# %% [markdown]
# https://www.dropbox.com/s/2oa1ulm6o45wond/ejemplo.R?dl=0

# %%
SABERPRO <- read.table(file ="https://gitlab.com/jamf05/random-uploads/-/raw/master/Entradas_de_extranjeros_a_Colombia.xls", sep = "\t", header=TRUE)
head(SABERPRO)
# Out:
#   Año.Mes.Nacionalidad.Femenino.Masculino.Indefinido.Total.Nueva.columna.georreferenciada
# 1 2012,Enero,Islas Alboran y Perejil,1,0,,1,POINT (4697157 -74140516)
# 2 2012,Enero,Albania,1,2,,3,POINT (4697157 -74140516)
# 3 2012,Enero,Alemania,11,16,,27,POINT (-4191162 -69941498)
# 4 2012,Enero,Alemania,1,1,,2,POINT (0.33002 -76876446)
# 5 2012,Enero,Alemania,63,102,,165,POINT (0.81488 -77356)
# 6 2012,Enero,Alemania,22,23,,45,POINT (10406342 -75527794)

# %%
summary(SABERPRO)
# Out:
#                                                      Año.Mes.Nacionalidad.Femenino.Masculino.Indefinido.Total.Nueva.columna.georreferenciada
#  2012,Enero,Reino Unido de Gran Bretaña e Irlanda del Norte,0,1,,1,POINT (3451668 -76532004)     :    3
#  2012,Abril,Países Bajos,1,0,,1,POINT (4815189 -75736374)                                        :    2
#  2012,Abril,Reino Unido de Gran Bretaña e Irlanda del Norte,0,1,,1,POINT (125862 -81702165)      :    2
#  2012,Abril,Reino Unido de Gran Bretaña e Irlanda del Norte,3,6,,9,POINT (7819 -72453013)        :    2
#  2012,Diciembre,Reino Unido de Gran Bretaña e Irlanda del Norte,0,1,,1,POINT (7128047 -73181317) :    2
#  2012,Diciembre,Reino Unido de Gran Bretaña e Irlanda del Norte,0,2,,2,POINT (10886686 -74776479):    2
#  (Other)                                                                                         :67656
